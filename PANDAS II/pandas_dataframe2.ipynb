# %% [markdown]
# PANDAS DATAFRAME CONTINUATION.............

# %%
import numpy as np 
import pandas as pd 

marks=pd.DataFrame([
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,70,14],
    [80,70,14]
],columns=['iq','marks','package'])
marks
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     70       14
# 4   80     70       14

# %%
marks.value_counts()
# Out:
# iq   marks  package
# 80   70     14         2
# 90   70     7          1
# 100  80     10         1
# 120  100    14         1
# Name: count, dtype: int64

# %%
a=pd.Series([1,1,1,2,4,32,22,3,3,2])
a.value_counts()  #more useful on series
# Out:
# 1     3
# 2     2
# 3     2
# 4     1
# 32    1
# 22    1
# Name: count, dtype: int64

# %%
#find which player has won most mom---> in finals and qualifiers

ipl=pd.read_csv('ipl-matches.csv')
~ipl['MatchNumber'].str.isdigit()
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
#how many matches each team has played
ipl.head()
ipl['Team1'].value_counts() + ipl['Team2'].value_counts()
# Out:
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                  63
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   46
# Punjab Kings                    28
# Rajasthan Royals               192
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    226
# Sunrisers Hyderabad            152
# Name: count, dtype: int64

# %%
a.sort_values()
# Out:
# 0     1
# 1     1
# 2     1
# 3     2
# 9     2
# 7     3
# 8     3
# 4     4
# 6    22
# 5    32
# dtype: int64

# %%
ipl.sort_values('Team1', ascending=False).head(7)  #sorting on the basis of columns
# Out:
#           ID       City        Date   Season MatchNumber                Team1  \
# 535   729311        NaN  2014-04-27     2014          17  Sunrisers Hyderabad
# 86   1254109      Dubai  2021-10-03     2021          49  Sunrisers Hyderabad
# 167  1216507        NaN  2020-10-11  2020/21          26  Sunrisers Hyderabad
# 460   829773  Hyderabad  2015-05-02     2015          34  Sunrisers Hyderabad
# 172  1216542        NaN  2020-10-08  2020/21          22  Sunrisers Hyderabad
# 445   829799  Hyderabad  2015-05-11     2015          48  Sunrisers Hyderabad
# 441   829807  Hyderabad  2015-05-15     2015          52  Sunrisers Hyderabad
#
#                            Team2                                      Venue  \
# 535          Chennai Super Kings                    Sharjah Cricket Stadium
# 86         Kolkata Knight Riders        Dubai International Cricket Stadium
# 167             Rajasthan Royals        Dubai International Cricket Stadium
# ...

# %%
mov=pd.read_csv("movies.csv")
mov.sort_values(['year_of_release','title_x'], ascending=[True,False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# rank(series)

batsman=pd.read_csv('batsman_runs_ipl.csv')
batsman.sample(10)
# Out:
#                    batter  batsman_run
# 590  X Thalaivan Sargunam           10
# 405              R Ashwin          647
# 493              SK Raina         5536
# 473               S Sohal          368
# 140             DJ Jacobs           92
# 185       Gurkeerat Singh          511
# 384              PA Patel         2848
# 235             JO Holder          247
# 99           Bipul Sharma          187
# 184             GR Napier           15

# %%
#sort_index(Series and dataframe)
batsman['batsman_run'].rank()
batsman.head()
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
marks={
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}
marks
# Out:
# {'maths': 67, 'english': 57, 'science': 89, 'hindi': 100}
